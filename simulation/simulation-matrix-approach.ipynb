# %%
import numpy as np
np.random.seed(42) # reproducibility

# %%
N_TREES = 50000
CELLS = 300
trees = np.random.randint(0,CELLS,(N_TREES,2)) # choose 50000 tree locations (assign fuel to half of cells)
fuel = np.zeros((CELLS,CELLS), dtype=np.uint8) # could be 1000x1000m
fuel[trees[:,0], trees[:,1]] = np.random.randint(0,255,N_TREES)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(fuel, cmap='bone')
plt.show()

# %%
state = np.zeros_like(fuel)
def ignite(state):
    state[state.shape[0]//2-1,state.shape[1]//2-1] = 1
    state[state.shape[0]//2-1,state.shape[1]//2] = 1
    state[state.shape[0]//2,state.shape[1]//2-1] = 1
    state[state.shape[0]//2,state.shape[1]//2] = 1
    
ignite(state)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(state, cmap='jet')
plt.show()

# %%
plt.imshow(count_neighbors_on_fire)

# %%
import scipy.signal
kernel = np.array([[1,1,1],[1,0,1],[1,1,1]])

N_STEPS = 200
state = np.zeros_like(fuel)
ignite(state)
states_history = np.zeros((N_STEPS,*state.shape))
for i in range(N_STEPS):
    states_history[i] = state
    states_list.append(state)
    count_neighbors_on_fire = scipy.signal.convolve2d(state, kernel, 'same')
    state += (count_neighbors_on_fire * np.random.random(state.shape) > 0.3) * fuel

# %%
import skimage.io
for i in range(N_STEPS):
    padded_n = '{0:03d}'.format(i)
    skimage.io.imsave(f'frames/frame{padded_n}.png',states_history[i])
# Out:
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame000.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame001.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 247.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame002.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 237.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame003.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 242.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame004.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame005.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 248.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame006.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 224.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame007.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 248.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame008.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame009.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 246.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame010.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 253.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame011.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame012.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame013.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 253.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame014.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame015.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame016.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame017.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 250.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame018.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 253.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame019.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 246.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame020.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame021.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame022.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame023.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame024.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame025.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame026.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame027.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame028.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame029.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame030.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame031.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame032.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame033.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame034.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 253.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame035.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame036.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame037.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame038.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame039.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame040.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame041.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame042.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame043.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame044.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame045.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame046.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame047.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame048.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# /home/tomek/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: frames/frame049.png is a low contrast image
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.

# %%
'{0:03d}'.format(4)
# Out:
# '004'

# %%
fig = plt.figure()
for st in states_list:
    plt.imshow(st)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#convert the frames to a video
#ffmpeg -i frame%03d.png -c:v libx264 -crf 0 -preset veryslow -c:a libmp3lame -b:a 320k output.mp4
